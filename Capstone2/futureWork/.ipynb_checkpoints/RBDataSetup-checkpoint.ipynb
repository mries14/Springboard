# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import glob
import seaborn as sns
import statsmodels.api as sm
import sklearn.preprocessing

# %%
# Read in rb stats files
rbStatsFiles = [filename for filename in glob.glob("C:/Users/Michael/Desktop/Springboard/Capstone2/csvFiles/DFS_Data/RB/stats/*.csv")]
rbStatsFiles[0]
# Out:
# 'C:/Users/Michael/Desktop/Springboard/Capstone2/csvFiles/DFS_Data/RB/stats\\RB2011.csv'

# %%
# Extract season and fix playoff weeks to match other tables

dfs = []
dfsPlayoffs = []

for i in range(int(len(rbStatsFiles)/2)):
    df = pd.read_csv(rbStatsFiles[i])
    df['season'] = rbStatsFiles[i][-8:-4]
    dfs.append(df)

# second half of list has playoff games, need to fix their weeks, then combine with first table    
for i in range(int(len(rbStatsFiles)/2),int(len(rbStatsFiles)/2)*2):
    dfPlayoffs = pd.read_csv(rbStatsFiles[i])
    dfPlayoffs['season'] = rbStatsFiles[i][-8:-4]
    dfsPlayoffs.append(dfPlayoffs)

    
for i in range(len(dfsPlayoffs)):
    dfsPlayoffs[i].loc[dfsPlayoffs[i].Week == 1, 'Week'] = 18
    dfsPlayoffs[i].loc[dfsPlayoffs[i].Week == 2, 'Week'] = 19
    dfsPlayoffs[i].loc[dfsPlayoffs[i].Week == 3, 'Week'] = 20
    dfsPlayoffs[i].loc[dfsPlayoffs[i].Week == 4, 'Week'] = 21


# dfsPlayoffs[-1].head()

rb = pd.concat(dfs,axis=0)
rb = rb.append(dfsPlayoffs)
rb.head()
# Out:
#    Rank                Name Team Position  Week Opponent  RushingAttempts  \
# 0     1        Arian Foster  HOU       RB     7      TEN               25
# 1     2  Maurice Jones-Drew  JAX       RB    14       TB               27
# 2     3         Kevin Smith  DET       RB    11      CAR               16
# 3     4          CJ Spiller  BUF       RB    15      MIA               12
# 4     5      Steven Jackson  LAR       RB     8       NO               25
#
#    RushingYards  RushingYardsPerAttempt  RushingTouchdowns  ReceivingTargets  \
# 0           115                     4.6                  2                 5
# 1            85                     3.1                  2                 6
# 2           140                     8.8                  2                 4
# 3            91                     7.6                  1                11
# 4           159                     6.4                  2                 5
#
#    Receptions  ReceivingYards  ReceivingTouchdowns  Fumbles  FumblesLost  \
# 0           5             119                    1        0            0
# 1           6              51                    2        0            0
# 2           4              61                    1        0            0
# 3           9              76                    1        0            0
# 4           4              32                    0        0            0
#
#    FantasyPointsPerGameFanDuel  FantasyPointsFanDuel season
# 0                         43.9                  43.9   2011
# 1                         40.6                  40.6   2011
# 2                         40.1                  40.1   2011
# 3                         33.2                  33.2   2011
# 4                         33.1                  33.1   2011

# %%
# Pull data from other workbooks
# %store -r awayTable
# %store -r homeTable
# %store -r awayMatchup
# %store -r homeMatchup
# %store -r oddsTable
# %store -r finalTeamGameDataTable

# %%
# Clean up the Team column to match the team column in awayTable and homeTable
teams1 = set(rb['Team'])
teams1.remove('SF')
teams2 = set(awayTable['team'])
teams2.remove('San Francisco 49ers')
t1List = list(teams1)
t2List = list(teams2)
t1List.sort()
t2List.sort()
zipTeams = zip(t1List, t2List)
teamDict = dict(list(zipTeams))
teamDict['SF'] = 'San Francisco 49ers'
teamDict
# Out:
# {'ARI': 'Arizona Cardinals',
#  'ATL': 'Atlanta Falcons',
#  'BAL': 'Baltimore Ravens',
#  'BUF': 'Buffalo Bills',
#  'CAR': 'Carolina Panthers',
#  'CHI': 'Chicago Bears',
#  'CIN': 'Cincinnati Bengals',
#  'CLE': 'Cleveland Browns',
#  'DAL': 'Dallas Cowboys',
#  'DEN': 'Denver Broncos',
#  'DET': 'Detroit Lions',
#  'GB': 'Green Bay Packers',
#  'HOU': 'Houston Texans',
#  'IND': 'Indianapolis Colts',
#  'JAX': 'Jacksonville Jaguars',
#  'KC': 'Kansas City Chiefs',
#  'LAC': 'Los Angeles Chargers',
#  'LAR': 'Los Angeles Rams',
#  'MIA': 'Miami Dolphins',
#  'MIN': 'Minnesota Vikings',
#  'NE': 'New England Patriots',
#  'NO': 'New Orleans Saints',
#  'NYG': 'New York Giants',
#  'NYJ': 'New York Jets',
#  'OAK': 'Oakland Raiders',
#  'PHI': 'Philadelphia Eagles',
#  'PIT': 'Pittsburgh Steelers',
#  'SEA': 'Seattle Seahawks',
#  'TB': 'Tampa Bay Buccaneers',
#  'TEN': 'Tennessee Titans',
#  'WAS': 'Washington Redskins',
#  'SF': 'San Francisco 49ers'}

# %%
teamDict2 = {'ARI': 'Cardinals',
 'ATL': 'Falcons',
 'BAL': 'Ravens',
 'BUF': 'Bills',
 'CAR': 'Panthers',
 'CHI': 'Bears',
 'CIN': 'Bengals',
 'CLE': 'Browns',
 'DAL': 'Cowboys',
 'DEN': 'Broncos',
 'DET': 'Lions',
 'GB': 'Packers',
 'HOU': 'Texans',
 'IND': 'Colts',
 'JAX': 'Jaguars',
 'KC': 'Chiefs',
 'LAC': 'Chargers',
 'LAR': 'Rams',
 'MIA': 'Dolphins',
 'MIN': 'Vikings',
 'NE': 'Patriots',
 'NO': 'Saints',
 'NYG': 'Giants',
 'NYJ': 'Jets',
 'OAK': 'Raiders',
 'PHI': 'Eagles',
 'PIT': 'Steelers',
 'SEA': 'Seahawks',
 'TB': 'Buccaneers',
 'TEN': 'Titans',
 'WAS': 'Redskins',
 'SF': '49ers'}

# %%
teamDict3 = zip(teamDict.values(),teamDict2.values())
teamDict3 = dict(list(teamDict3))
teamDict3
# Out:
# {'Arizona Cardinals': 'Cardinals',
#  'Atlanta Falcons': 'Falcons',
#  'Baltimore Ravens': 'Ravens',
#  'Buffalo Bills': 'Bills',
#  'Carolina Panthers': 'Panthers',
#  'Chicago Bears': 'Bears',
#  'Cincinnati Bengals': 'Bengals',
#  'Cleveland Browns': 'Browns',
#  'Dallas Cowboys': 'Cowboys',
#  'Denver Broncos': 'Broncos',
#  'Detroit Lions': 'Lions',
#  'Green Bay Packers': 'Packers',
#  'Houston Texans': 'Texans',
#  'Indianapolis Colts': 'Colts',
#  'Jacksonville Jaguars': 'Jaguars',
#  'Kansas City Chiefs': 'Chiefs',
#  'Los Angeles Chargers': 'Chargers',
#  'Los Angeles Rams': 'Rams',
#  'Miami Dolphins': 'Dolphins',
#  'Minnesota Vikings': 'Vikings',
#  'New England Patriots': 'Patriots',
#  'New Orleans Saints': 'Saints',
#  'New York Giants': 'Giants',
#  'New York Jets': 'Jets',
#  'Oakland Raiders': 'Raiders',
#  'Philadelphia Eagles': 'Eagles',
#  'Pittsburgh Steelers': 'Steelers',
#  'Seattle Seahawks': 'Seahawks',
#  'Tampa Bay Buccaneers': 'Buccaneers',
#  'Tennessee Titans': 'Titans',
#  'Washington Redskins': 'Redskins',
#  'San Francisco 49ers': '49ers'}

# %%
# Map dictionary keys to new values so we have matching team/opponent names across the board
rb['Team'] = rb['Team'].map(teamDict2)
rb['Opponent'] = rb['Opponent'].map(teamDict2)

# qbSalaries['Team'] = qbSalaries['Team'].map(teamDict2)
# qbSalaries['Opponent'] = qbSalaries['Opponent'].map(teamDict2)


awayMatchup['team_x'] = awayMatchup['team_x'].map(teamDict3)
awayMatchup['team_y'] = awayMatchup['team_y'].map(teamDict3)
homeMatchup['team_x'] = homeMatchup['team_x'].map(teamDict3)
homeMatchup['team_y'] = homeMatchup['team_y'].map(teamDict3)

awayMatchup.head()
# Out:
#          gameId       date  season  week     team_x homeAway  \
# 0  201811110kan 2018-11-11    2018    10  Cardinals     away
# 1  201610300car 2016-10-30    2016     8  Cardinals     away
# 2  201612240sea 2016-12-24    2016    16  Cardinals     away
# 3  201812300sea 2018-12-30    2018    17  Cardinals     away
# 4  201712310sea 2017-12-31    2017    17  Cardinals     away
#
#                    stadium      roof surface      avgPf  ...  defDvoa  \
# 0        Arrowhead Stadium  outdoors   grass  14.857143  ...    0.076
# 1  Bank of America Stadium  outdoors   grass  22.714286  ...    0.031
# 2        CenturyLink Field  outdoors    turf  25.857143  ...   -0.128
# 3        CenturyLink Field  outdoors    turf  13.000000  ...    0.010
# 4        CenturyLink Field  outdoors    turf  18.571429  ...   -0.052
#
#    ptsMatchup  offMatchup  ovrMatchup  passMatchup  pblkMatchup  runMatchup  \
# 0   37.857143  -10.285714  -13.857143   -10.600000   -16.071429    0.657143
# 1   51.285714    3.000000    4.457143    -2.228571     3.257143   -3.157143
# 2   43.857143    0.757143   -3.042857     7.171429   -14.242857   -9.314286
# 3   36.857143   -7.400000  -13.642857    -7.628571    -6.100000   -7.414286
# 4   41.000000   -9.228571   -2.514286   -15.628571    -5.085714   -6.285714
#
#    offDvoaMatchup  totalDvoaMatchup  pf
# 0          -0.307            -0.764  14
# 1          -0.041             0.170  20
# 2          -0.225            -0.155  34
# 3          -0.406            -0.520  24
# 4          -0.254            -0.144  26
#
# [5 rows x 41 columns]

# %%
#turn seasons to numeric instead of strings
rb['season'] = pd.to_numeric(rb['season'])
# qbSalaries['season'] = pd.to_numeric(qbSalaries['season'])

# Merge qb table with matchup tables, then puth the two together
rbTable1 = pd.merge(rb,awayMatchup,how='inner',left_on=['Team','season','Week'],right_on=['team_x','season','week'])

rbTable2 = pd.merge(rb,homeMatchup,how='inner',left_on=['Team','season','Week'],right_on=['team_x','season','week'])

rbTableFinal = pd.concat([rbTable1,rbTable2],axis=0)

rbTableFinal.head()

# rbTableFinal = pd.merge(rbTable,rbSalaries,how='inner',left_on=['Name', 'Team', 'Position', 'Week', 'Opponent','season'],right_on=['Name', 'Team', 'Position', 'Week', 'Opponent','season'])
# rbTableFinal.columns
# Out:
#    Rank              Name    Team Position  Week Opponent  RushingAttempts  \
# 0     1      Arian Foster  Texans       RB     7   Titans               25
# 1   388          Ben Tate  Texans       RB     7   Titans               15
# 2  1312      Derrick Ward  Texans       RB     7   Titans                5
# 3  1454  Lawrence Vickers  Texans       FB     7   Titans                1
# 4     7          Ray Rice  Ravens       RB    17  Bengals               24
#
#    RushingYards  RushingYardsPerAttempt  RushingTouchdowns  ...  defDvoa  \
# 0           115                     4.6                  2  ...   -0.007
# 1           104                     6.9                  0  ...   -0.007
# 2             7                     1.4                  0  ...   -0.007
# 3             0                     0.0                  0  ...   -0.007
# 4           191                     8.0                  2  ...    0.039
#
#    ptsMatchup  offMatchup  ovrMatchup  passMatchup  pblkMatchup  runMatchup  \
# 0   46.571429   14.114286    4.500000     9.714286    15.371429   -5.071429
# 1   46.571429   14.114286    4.500000     9.714286    15.371429   -5.071429
# 2   46.571429   14.114286    4.500000     9.714286    15.371429   -5.071429
# 3   46.571429   14.114286    4.500000     9.714286    15.371429   -5.071429
# 4   43.571429    7.800000    7.657143     6.257143    12.628571    0.428571
#
#    offDvoaMatchup  totalDvoaMatchup  pf
# 0           0.090            -0.115  41
# 1           0.090            -0.115  41
# 2           0.090            -0.115  41
# 3           0.090            -0.115  41
# 4           0.108             0.171  24
#
# [5 rows x 59 columns]

# %%
rbs = rbTableFinal[(rbTableFinal['RushingAttempts'] + rbTableFinal['ReceivingTargets'] >= 10)]

# %%
rbs.head()
# Out:
#    Rank          Name    Team Position  Week    Opponent  RushingAttempts  \
# 0     1  Arian Foster  Texans       RB     7      Titans               25
# 1   388      Ben Tate  Texans       RB     7      Titans               15
# 4     7      Ray Rice  Ravens       RB    17     Bengals               24
# 7     8  Arian Foster  Texans       RB    10  Buccaneers               17
# 8   303      Ben Tate  Texans       RB    10  Buccaneers               13
#
#    RushingYards  RushingYardsPerAttempt  RushingTouchdowns  ...  defDvoa  \
# 0           115                     4.6                  2  ...   -0.007
# 1           104                     6.9                  0  ...   -0.007
# 4           191                     8.0                  2  ...    0.039
# 7            84                     4.9                  1  ...    0.140
# 8            63                     4.8                  1  ...    0.140
#
#    ptsMatchup  offMatchup  ovrMatchup  passMatchup  pblkMatchup  runMatchup  \
# 0   46.571429   14.114286    4.500000     9.714286    15.371429   -5.071429
# 1   46.571429   14.114286    4.500000     9.714286    15.371429   -5.071429
# 4   43.571429    7.800000    7.657143     6.257143    12.628571    0.428571
# 7   49.714286   19.128571   13.871429    18.585714    11.614286    4.942857
# 8   49.714286   19.128571   13.871429    18.585714    11.614286    4.942857
#
#    offDvoaMatchup  totalDvoaMatchup  pf
# 0           0.090            -0.115  41
# 1           0.090            -0.115  41
# 4           0.108             0.171  24
# 7           0.343             0.305  37
# 8           0.343             0.305  37
#
# [5 rows x 59 columns]

# %%
rbs = pd.merge(rbs,oddsTable,how='right',left_on=['Team','season','Week'],right_on=['team','season','week'])

# %%
rbs.loc[rbs.pf > rbs.pa, 'winLose'] = 'Win'
rbs.loc[rbs.pf < rbs.pa, 'winLose'] = 'Loss'
rbs.loc[rbs.pf == rbs.pa, 'winLose'] = 'Tie'

rbs.loc[rbs.totalScore > rbs.total, 'result'] = 'over'
rbs.loc[rbs.totalScore < rbs.total, 'result'] = 'under'
rbs.loc[rbs.totalScore == rbs.total, 'result'] = 'push'

# %%
rbs.columns
# Out:
# Index(['Rank', 'Name', 'Team', 'Position', 'Week', 'Opponent',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'ReceivingTargets', 'Receptions', 'ReceivingYards',
#        'ReceivingTouchdowns', 'Fumbles', 'FumblesLost',
#        'FantasyPointsPerGameFanDuel', 'FantasyPointsFanDuel', 'season',
#        'gameId', 'date_x', 'week_x', 'team_x', 'homeAway', 'stadium', 'roof',
#        'surface', 'avgPf', 'avgOvr_x', 'avgOff', 'avgPass', 'avgPblk',
#        'avgRecv', 'avgRun', 'avgRblk', 'totalDvoa_x', 'offDvoa', 'stDvoa',
#        'overUnder', 'pa', 'totalScore', 'team_y', 'avgPa', 'avgOvr_y',
#        'avgDef', 'avgRdef', 'avgPrsh', 'avgCov', 'totalDvoa_y', 'defDvoa',
#        'ptsMatchup', 'offMatchup', 'ovrMatchup', 'passMatchup', 'pblkMatchup',
#        'runMatchup', 'offDvoaMatchup', 'totalDvoaMatchup', 'pf', 'date_y',
#        'week_y', 'team', 'spread', 'total', 'moneyLine', 'homeOrAway',
#        'impliedTotal', 'winLose', 'result'],
#       dtype='object')

# %%
rbVars = ['Name', 'Team', 'Position','season', 'Week', 'Opponent', 'homeAway', 'surface','RushingAttempts', 'ReceivingTargets', 'avgRdef','defDvoa','passMatchup','offMatchup','offDvoaMatchup','spread','total', 'moneyLine','impliedTotal', 'winLose', 'result','FantasyPointsFanDuel']

# %%
newRbs = rbs[rbVars]

# %%
corr = newRbs.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col2 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col3 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col4 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col5 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col8 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col9 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col10 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col11 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col12 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row0_col13 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col3 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col4 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col6 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col7 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col8 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col9 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col10 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col12 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row1_col13 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col0 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col1 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col4 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col6 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col7 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col8 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col9 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col10 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col11 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col12 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row2_col13 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col0 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col1 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col4 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col6 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col7 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col8 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col9 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col10 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col11 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col12 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row3_col13 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row4_col0 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row4_col1 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row4_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_103feb14_e75e_11e9_8ad3_3402864a3df9row4_col3 {
#             background-color:  #7597f6;
#             colo

# %%
sb = newRbs[(newRbs['Name'] == 'Christian McCaffrey') & (newRbs['total'] >= 44)]
sb = sb[(sb['RushingAttempts'] + sb['ReceivingTargets']) >= 16]
sb[['Name','Team','Week','Opponent','homeAway','spread','FantasyPointsFanDuel']].sort_values('FantasyPointsFanDuel',ascending=False)
# Out:
#                      Name      Team  Week    Opponent homeAway  spread  \
# 4895  Christian McCaffrey  Panthers  12.0    Seahawks     home    -3.0
# 2260  Christian McCaffrey  Panthers  10.0    Steelers     away     3.5
# 4912  Christian McCaffrey  Panthers   9.0  Buccaneers     home    -6.5
# 2289  Christian McCaffrey  Panthers  13.0  Buccaneers     away    -3.5
# 2298  Christian McCaffrey  Panthers  14.0      Browns     away    -1.0
# 4936  Christian McCaffrey  Panthers  16.0     Falcons     home     3.0
# 4589  Christian McCaffrey  Panthers  15.0     Packers     home    -3.0
# 4960  Christian McCaffrey  Panthers  15.0      Saints     home     6.0
# 4968  Christian McCaffrey  Panthers   3.0     Bengals     home    -3.0
# 4975  Christian McCaffrey  Panthers   8.0      Ravens     home     2.5
# 4646  Christian McCaffrey  Panthers   6.0      Eagles     home    -3.0
# 2418  Christian McCaffrey  Panthers  11.0       Lions     away    -4.0
# 2486  Christian McCaffrey  Panthers   6.0    Redskins     away    -1.0
# 2018  Christian McCaffrey  Panthers   1.0       49ers     away    -4.5
#
#       FantasyPointsFanDuel
# 4895                  41.2
# 2260                  34.3
# 4912                  30.2
# 2289                  26.6
# 2298                  25.1
# 4936                  23.8
# 4589                  22.6
# 4960                  22.0
# 4968                  20.4
# 4975                  19.6
# 4646                  17.4
# 2418                  14.0
# 2486                  10.1
# 2018                   9.0

# %%
sb = newRbs[(newRbs['Team'] == 'Bengals')]
sb = sb[(sb['season'] >= 2015) & (sb['RushingAttempts'] + sb['ReceivingTargets'] > 15) & (sb['result'] == 'over')]#.sort_values('season')# & (sb['homeAway'] == 'home')]
# sb = sb[(sb['Name'] == 'Todd Gurley') | (sb['Name'] == 'CJ Anderson')]
# sb.corr().style.background_gradient(cmap='coolwarm')

# %%
gurley = sb[['Name','season','Week','Opponent', 'homeAway','RushingAttempts','ReceivingTargets','defDvoa','offDvoaMatchup','spread','total','result','winLose','impliedTotal','FantasyPointsFanDuel']]# & (sb['homeAway'] == 'home')]
gurley.sort_values('FantasyPointsFanDuel',ascending=False)
# Out:
#                  Name  season  Week    Opponent homeAway  RushingAttempts  \
# 4920        Joe Mixon    2018   8.0  Buccaneers     home             21.0
# 4928        Joe Mixon    2018  15.0     Raiders     home             27.0
# 4576        Joe Mixon    2017  12.0      Browns     home             23.0
# 2311  Giovani Bernard    2018   4.0     Falcons     away             15.0
# 2312        Joe Mixon    2018   1.0       Colts     away             17.0
# 4276      Jeremy Hill    2016   3.0     Broncos     home             17.0
# 4984        Joe Mixon    2018  12.0      Browns     home             14.0
# 1353  Giovani Bernard    2015  11.0   Cardinals     away              6.0
# 1359      Jeremy Hill    2015   1.0     Raiders     away             19.0
# 2374  Giovani Bernard    2018   3.0    Panthers     away             12.0
# 4242  Giovani Bernard    2016   7.0      Browns     home             17.0
# 4378      Jeremy Hill    2016   8.0    Redskins     home             20.0
# 1425      Jeremy Hill    2015   6.0       Bills     away             16.0
# 4062  Giovani Bernard    2015   5.0    Seahawks     home             15.0
# 2099        Joe Mixon    2017   3.0     Packers     away             18.0
# 4419      Jeremy Hill    2016  13.0      Eagles     home             23.0
# 1763  Giovani Bernard    2016   6.0    Patriots     away             15.0
# 2141  Giovani Bernard    2017  17.0      Ravens     away             10.0
# 1497  Giovani Bernard    2015   3.0      Ravens     away             13.0
# 5173        Joe Mixon    2018   2.0      Ravens     home             21.0
# 2142        Joe Mixon    2017  17.0      Ravens     away             18.0
#
#       ReceivingTargets  defDvoa  offDvoaMatchup  spread  total result winLose  \
# 4920               4.0    0.226           0.248    -3.5   54.5   over     Win
# 4928               4.0    0.158           0.153    -3.0   45.5   over     Win
# 4576               3.0   -0.029          -0.142    -7.5   39.0   over     Win
# 2311               4.0    0.229           0.402     3.5   52.5   over     Win
# 2312               7.0    0.041           0.032    -1.0   47.5   over     Win
# 4276               0.0   -0.146          -0.098    -3.5   41.5   over    Loss
# 4984               7.0   -0.078          -0.078     1.0   47.0   over    Loss
# 1353              10.0   -0.141           0.039     4.0   48.0   over    Loss
# 1359               0.0    0.004           0.039    -3.0   43.0   over     Win
# 2374               9.0    0.112           0.294     3.0   44.0   over    Loss
# 4242               2.0    0.126           0.139   -11.0   46.5   over     Win
# 4378               1.0    0.038           0.158    -3.0   49.0   over     Tie
# 1425               1.0   -0.073           0.229    -3.0   42.0   over     Win
# 4062               8.0   -0.009           0.356    -3.0   44.0   over     Win
# 2099               3.0    0.043          -0.557     7.0   47.5   over    Loss
# 4419               3.0   -0.163          -0.133    -1.5   42.0   over     Win
# 1763               5.0    0.070           0.093     7.5   48.0   over    Loss
# 2141               9.0   -0.167          -0.270     8.5   40.0   over     Win
# 1497               4.0    0.016           0.316     2.0   46.0   over     Win
# 5173               1.0   -0.659          -0.509     1.0   43.0   over     Win
# 2142               1.0   -0.167          -0.270     8.5   40.0   over     Win
#
#       impliedTotal  FantasyPointsFanDuel
# 4920         29.00                  27.3
# 4928         24.25                  26.0
# 4576         23.25                  24.0
# 2311         24.50                  23.6
# 2312         24.25                  23.4
# 4276         22.50                  21.7
# 4984         23.00                  19.0
# 1353         22.00                  18.6
# 1359         23.00                  18.3
# 2374         20.50                  17.1
# 4242         28.75                  15.2
# 4378         26.00                  13.8
# 1425         22.50                  13.4
# 4062         23.50                  12.6
# 2099         20.25                  11.6
# 4419         21.75                  11.5
# 1763         20.25                  11.4
# 2141         15.75                  10.0
# 1497         22.00                   9.8
# 5173         21.00                   9.2
# 2142         15.75                   8.2

# %%
targetPts = 18
totalInstances = len(gurley)
timesHit = len(gurley[gurley['FantasyPointsFanDuel'] > targetPts])

print(timesHit)
print(totalInstances)
print(timesHit/totalInstances)
# Out:
# 35
# 55
# 0.6363636363636364

# %%
cmc = newRbs[(newRbs['Name'] == 'Christian McCaffrey')]
cmc = cmc[(cmc['season'] >= 2018) & (cmc['RushingAttempts'] + cmc['ReceivingTargets'] > 13)]#.sort_values('season')# & (sb['homeAway'] == 'home')]
cmc[cmc['total'] > 46]
# Out:
#                      Name      Team Position  season  Week    Opponent  \
# 2260  Christian McCaffrey  Panthers       RB    2018  10.0    Steelers
# 2289  Christian McCaffrey  Panthers       RB    2018  13.0  Buccaneers
# 2298  Christian McCaffrey  Panthers       RB    2018  14.0      Browns
# 2418  Christian McCaffrey  Panthers       RB    2018  11.0       Lions
# 4895  Christian McCaffrey  Panthers       RB    2018  12.0    Seahawks
# 4912  Christian McCaffrey  Panthers       RB    2018   9.0  Buccaneers
# 4960  Christian McCaffrey  Panthers       RB    2018  15.0      Saints
#
#      homeAway surface  RushingAttempts  ReceivingTargets  ...  passMatchup  \
# 2260     away   grass             14.0               5.0  ...    14.414286
# 2289     away   grass             10.0              10.0  ...    10.828571
# 2298     away   grass             16.0               7.0  ...     5.057143
# 2418     away    turf             13.0               8.0  ...    13.328571
# 4895     home   grass             17.0              11.0  ...     9.557143
# 4912     home   grass             17.0               6.0  ...    12.385714
# 4960     home   grass             15.0              11.0  ...    -3.685714
#
#       offMatchup  offDvoaMatchup  spread  total  moneyLine  impliedTotal  \
# 2260    6.600000           0.206     3.5   51.0      170.0         23.75
# 2289   14.942857           0.295    -3.5   51.5     -178.0         27.50
# 2298    7.928571           0.039    -1.0   48.0     -105.0         24.50
# 2418    6.028571           0.314    -4.0   48.5     -200.0         26.25
# 4895    5.971429           0.062    -3.0   46.5     -160.0         24.75
# 4912    9.042857           0.394    -6.5   56.0     -290.0         31.25
# 4960   -8.928571           0.079     6.0   50.5      215.0         22.25
#
#       winLose  result FantasyPointsFanDuel
# 2260     Loss    over                 34.3
# 2289     Loss   under                 26.6
# 2298     Loss   under                 25.1
# 2418     Loss   under                 14.0
# 4895     Loss    over                 41.2
# 4912      Win    over                 30.2
# 4960     Loss   under                 22.0
#
# [7 rows x 22 columns]

# %%
sns.regplot(sb['defDvoa'],sb['FantasyPointsFanDuel'])

# %%
class RB:
    
    rbVars = ['Name','FanDuelSalary', 'season', 'Week', 'Opponent', 'homeOrAway', 'impliedTotal', 'winLose', 'result','cashTarget', 'FantasyPointsFanDuel']
    
    def __init__(self,name,table):
        self.name = name
        self.table = table[table['Name'] == name]
        
    def get_table(self):
        return self.table
    
    def corrMatrix(self,features):
        correlations = self.table[features].corr()
        return correlations.style.background_gradient(cmap='coolwarm')
    
    def scatter(self,var1,var2):
        plt.scatter(self.table[var1],self.table[var2])
        plt.title(self.name)
        plt.xlabel(var1)
        plt.ylabel(var2)
        plt.show()
        
    def impliedTot(self, value):
        return self.table[self.table['impliedTotal'] >= value][qbVars]

# %%
sb = newRbs[(newRbs['Name'] == 'Christian McCaffrey') & (newRbs['season'] == 2018)]
sb.corr().style.background_gradient(cmap='coolwarm')
# Out:
# C:\Python37\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_cf572810_d010_11e9_a247_3402864a3df9row0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row2_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row3_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf572810_d010_11e9_a247_3402864a3df9row4_col3 {
#             background-color:  #3b4cc0;
#             colo

# %%
sb[sb['total'] >= 45]
# Out:
#                      Name      Team Position  season  Week    Opponent  \
# 2260  Christian McCaffrey  Panthers       RB    2018  10.0    Steelers
# 2289  Christian McCaffrey  Panthers       RB    2018  13.0  Buccaneers
# 2298  Christian McCaffrey  Panthers       RB    2018  14.0      Browns
# 2418  Christian McCaffrey  Panthers       RB    2018  11.0       Lions
# 4895  Christian McCaffrey  Panthers       RB    2018  12.0    Seahawks
# 4912  Christian McCaffrey  Panthers       RB    2018   9.0  Buccaneers
# 4936  Christian McCaffrey  Panthers       RB    2018  16.0     Falcons
# 4960  Christian McCaffrey  Panthers       RB    2018  15.0      Saints
#
#      homeAway surface  RushingAttempts  ReceivingTargets  ...  passMatchup  \
# 2260     away   grass             14.0               5.0  ...    14.414286
# 2289     away   grass             10.0              10.0  ...    10.828571
# 2298     away   grass             16.0               7.0  ...     5.057143
# 2418     away    turf             13.0               8.0  ...    13.328571
# 4895     home   grass             17.0              11.0  ...     9.557143
# 4912     home   grass             17.0               6.0  ...    12.385714
# 4936     home   grass             21.0              13.0  ...    -3.414286
# 4960     home   grass             15.0              11.0  ...    -3.685714
#
#       offMatchup  offDvoaMatchup  spread  total  moneyLine  impliedTotal  \
# 2260    6.600000           0.206     3.5   51.0      170.0         23.75
# 2289   14.942857           0.295    -3.5   51.5     -178.0         27.50
# 2298    7.928571           0.039    -1.0   48.0     -105.0         24.50
# 2418    6.028571           0.314    -4.0   48.5     -200.0         26.25
# 4895    5.971429           0.062    -3.0   46.5     -160.0         24.75
# 4912    9.042857           0.394    -6.5   56.0     -290.0         31.25
# 4936   -2.214286           0.233     3.0   46.0      138.0         21.50
# 4960   -8.928571           0.079     6.0   50.5      215.0         22.25
#
#       winLose  result FantasyPointsFanDuel
# 2260     Loss    over                 34.3
# 2289     Loss   under                 26.6
# 2298     Loss   under                 25.1
# 2418     Loss   under                 14.0
# 4895     Loss    over                 41.2
# 4912      Win    over                 30.2
# 4936     Loss   under                 23.8
# 4960     Loss   under                 22.0
#
# [8 rows x 22 columns]
